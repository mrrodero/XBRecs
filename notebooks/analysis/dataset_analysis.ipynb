# %% [markdown]
# ## Análisis del dataset GoodBooks10k-Extended

# %% [markdown]
# ### Tabla de contenidos
#
# - [Introducción](#intro)
# - [Análisis del dataset de libros](#libros)
# - [Análisis del dataset de ratings de usuarios](#ratings)
# - [Otros datasets](#otros)

# %% [markdown]
# ### <a id="intro"></a> Introducción

# %% [markdown]
# Este dataset procede del repositorio [GoodBooks 10k Extended](https://github.com/malcolmosh/goodbooks-10k-extended). A lo largo del *notebook* iremos analizando aspectos de interés del dataset. También lo modificaremos para que se ajuste al futuro sistema recomendador de libros, consistente en comprensión de lenguaje natural de las sinopsis, en combinación con el contenido de otros atributos.

# %% [markdown]
# ### <a id="libros"></a> Análisis del dataset de libros

# %%
import pandas as pd
from ast import literal_eval

path = '../../datasets/goodbooks_ext/'
books = pd.read_csv(path + 'books_enriched.csv', index_col=[0], converters={"genres": literal_eval})

# %% [markdown]
# Comprobamos la información del dataset en cuanto a las columnas de las que consiste, así como los tipos de los datos presentes en ellas y cuántos de ellos son no nulos.

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10000 entries, 0 to 9999
# Data columns (total 29 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      10000 non-null  int64
#  1   authors                    10000 non-null  object
#  2   average_rating             10000 non-null  float64
#  3   best_book_id               10000 non-null  int64
#  4   book_id                    10000 non-null  int64
#  5   books_count                10000 non-null  int64
#  6   description                9943 non-null   object
#  7   genres                     10000 non-null  object
#  8   goodreads_book_id          10000 non-null  int64
#  9   image_url                  10000 non-null  object
#  10  isbn                       9300 non-null   object
#  11  isbn13                     9415 non-null   float64
#  12  language_code              10000 non-null  object
#  13  original_publication_year  9979 non-null   float64
#  14  original_title             9415 non-null   object
#  15  pages                      9927 non-null   float64
#  16  publishDate                9992 non-null   object
#  17  ratings_1                  10000 non-null  int64
#  18  ratings_2                  10000 non-null  int64
#  19  ratings_3                  10000 non-null  int64
#  20  ratings_4                  10000 non-null  int64
#  21  ratings_5                  10000 non-null  int64
#  22  ratings_count              10000 non-null  int64
#  23  small_image_url            10000 non-null  object
#  24  title                      10000 non-null  object
#  25  work_id                    10000 non-null  int64
#  26  work_ratings_count         10000 non-null  int64
#  27  work_text_reviews_count    10000 non-null  int64
#  28  authors_2                  10000 non-null  object
# dtypes: float64(4), int64(14), object(11)
# memory usage: 2.3+ MB

# %% [markdown]
# Para nuestro proyecto, los atributos de mayor interés serán:
# - `description`: ofrece una descripción del libro (sinopsis, u otra información del producto)
# - `title`/`original_title`: título del libro (o su versión original)
# - `authors`/`authors_2`: autores y colaboradores (ilustradores, traductores, etc.) del libro
# - `genres`: géneros en los cuales cae el libro
#
# Esto se debe a que enfocaremos el sistema a recomendaciones de tipo *Content-Based*, apoyándonos en comprensión de lenguaje natural para extraer contenido útil de las descripciones de los libros del dataset.
#
# Otros atributos menores, pero que también podrían ser útiles para recomendaciones en base al contenido o el estilo son los siguientes:
# - `pages`: número de páginas del libro
# - `original_publication_year`: año original de publicación del libro
#
# Adicionalmente, los atributos que tienen que ver con el número de reviews (principalmente `work_ratings_count`) nos serán de utilidad. Esto es, para comprobar si un libro ha sido lo suficientemente valorado como para presentar una nota que se ajuste a la opinión real de cualquier persona que escoja leer esa obra. El atributo `work_text_reviews_count` puede servir para entender si un libro concita un interés de importancia, pues los usuarios que lo leyeron también dieron una valoración escrita, más extensa (requiere un esfuerzo mayor).
#
# Por supuesto, `average_rating` jugará también un papel fundamental si decidimos hacer un filtrado a partir de la nota que tengan los libros candidatos a ser recomendados. Esto supondría una hibridación del sistema recomendador entre *Content-Based* y *Collaborative Filtering*.

# %% [markdown]
# Por otra parte, hay algunos atributos que no nos interesarán. Estos son `index`, `books_count`, `best_book_id`, `goodreads_book_id` y `ratings_count`.
#
# Algunos de estos se refieren a los identificadores que se les asignó en una de las colecciones de *GoodReads* sobre los mejores libros de la historia (en opinión de usuarios).
#
# En el caso de `ratings_count`, hemos decidido eliminar esta columna, ya que corresponde a la edición del libro de la que se hace referencia en el dataset, pero no a la obra como tal. Para ese dato ya contamos con el atributo `work_ratings_count`, mencionado con anterioridad.

# %%
del books['index'], books['best_book_id'], books['goodreads_book_id']
del books['books_count'], books['ratings_count']
books.head(20)
# Out:
#                                               authors  average_rating  \
# 0                                 ['Suzanne Collins']            4.34
# 1                   ['J.K. Rowling', 'Mary GrandPré']            4.44
# 2                                 ['Stephenie Meyer']            3.57
# 3                                      ['Harper Lee']            4.25
# 4                             ['F. Scott Fitzgerald']            3.89
# 5                                      ['John Green']            4.26
# 6                                  ['J.R.R. Tolkien']            4.25
# 7                                   ['J.D. Salinger']            3.79
# 8                                       ['Dan Brown']            3.85
# 9                                     ['Jane Austen']            4.24
# 10                                ['Khaled Hosseini']            4.26
# 11                                  ['Veronica Roth']            4.24
# 12  ['Anne Frank', 'Eleanor Roosevelt', 'B.M. Mooy...            4.10
# 13                   ['Stieg Larsson', 'Reg Keeland']            4.11
# 14                                ['Suzanne Collins']            4.30
# 15    ['J.K. Rowling', 'Mary GrandPré', 'Rufus Beck']            4.53
# 16                                ['Suzanne Collins']            4.03
# 17                  ['J.K. Rowling', 'Mary GrandPré']            4.46
# 18                                   ['Alice Sebold']            3.77
# 19                  ['J.K. Rowling', 'Mary GrandPré']            4.37
#
#     book_id                                        description  \
# 0         1  WINNING MEANS FAME AND FORTUNE.LOSING MEANS CE...
# 1         2  Harry Potter's life is miserable. His parents ...
# 2         3  About three things I was absolutely positive.\...
# 3         4  The unforgettable novel of a childhood in a sl...
# 4         5  Alternate Cover Edition ISBN: 0743273567 (ISBN...
# 5         6  Despite the tumor-shrinking medical miracle th...
# 6         7  In a hole in the ground there lived a hobbit. ...
# 7         8  The hero-narrator of The Catcher in the Rye is...
# 8         9  World-renowned Harvard symbologist Robert Lang...
# 9        10  Alternate cover edition of ISBN 9780679783268S...
# 10       11  The unforgettable, heartbreaking story of the ...
# 11       12  In Beatrice Prior's dystopian Chicago world, s...
# 12       15  Discovered in the attic in which she spent the...
# 13       16  Harriet Vanger, a scion of one of Sweden’s wea...
# 14       17  SPARKS ARE IGNITING.FLAMES ARE SPREADING.AND T...
# 15       18  Harry Potter's third year at Hogwarts is full ...
# 18                                   The Lovely Bones   1145090
# 19  Harry Potter and the Chamber of Secrets (Harry...   6231171
#
#     work_ratings_count work_text_reviews_count  \
# 0              4942365                  155254
# 1              4800065                   75867
# 2              3916824                   95009
# 3              3340896                   72586
# 4              2773745                   51992
# 5              2478609                  140739
# 6              2196809                   37653
# 7              2120637                   44920
# 8              2078754                   25112
# 9              2191465                   49152
# 10             1878095                   59730
# 11             2216814                  101023
# 12             2024493                   20825
# 13             1929834                   62543
# 14             1988079                   88538
# 15             1969375                   36099
# 16             1870748                   96274
# 17             1840548                   28685
# 18             1661562                   36642
# 19             1906199                   34172
#
#                                             authors_2
# 0                                 ['Suzanne Collins']
# 1                   ['J.K. Rowling', 'Mary GrandPré']
# 2                                 ['Stephenie Meyer']
# 3                                      ['Harper Lee']
# 4                             ['F. Scott Fitzgerald']
# 5                                      ['John Green']
# 6                                  ['J.R.R. Tolkien']
# 7                                   ['J.D. Salinger']
# 8                                       ['Dan Brown']
# 9                                     ['Jane Austen']
# 10                                ['Khaled Hosseini']
# 11                                  ['Veronica Roth']
# 12  ['Anne Frank', 'Eleanor Roosevelt', 'B.M. Mooy...
# 13                   ['Stieg Larsson', 'Reg Keeland']
# 14                                ['Suzanne Collins']
# 15    ['J.K. Rowling', 'Mary GrandPré', 'Rufus Beck']
# 16                                ['Suzanne Collins']
# 17                  ['J.K. Rowling', 'Mary GrandPré']
# 18                                   ['Alice Sebold']
# 19                  ['J.K. Rowling', 'Mary GrandPré']
#
# [20 rows x 24 columns]

# %%
books.iloc[[0, 16, 14, 9904, 9903, 2368, 11, 5642, 7162, 3077]][['book_id', 'title', 'authors']]
# Out:
#       book_id                                          title  \
# 0           1        The Hunger Games (The Hunger Games, #1)
# 16         20              Mockingjay (The Hunger Games, #3)
# 14         17           Catching Fire (The Hunger Games, #2)
# 9904     9713              The Wild Ones (The Wild Ones, #1)
# 9903     9709                     The Hunger Pains: A Parody
# 2368     2533  The Winner's Curse (The Winner's Trilogy, #1)
# 11         12                      Divergent (Divergent, #1)
# 5642     6423   The Winner's Kiss (The Winner's Trilogy, #3)
# 7162     8476           My Soul to Save (Soul Screamers, #2)
# 3077     3318                  Birthmarked (Birthmarked, #1)
#
#                         authors
# 0           ['Suzanne Collins']
# 16          ['Suzanne Collins']
# 14          ['Suzanne Collins']
# 9904  ['[The Harvard Lampoon]']
# 9903  ['[The Harvard Lampoon]']
# 2368         ['Marie Rutkoski']
# 11            ['Veronica Roth']
# 5642         ['Marie Rutkoski']
# 7162         ['Rachel Vincent']
# 3077      ["Caragh M. O'Brien"]

# %%
books[books['book_id'].isin([1, 17, 20, 9709, 9713, 2533, 12, 6423, 8476, 3318])][['book_id', 'title', 'authors']]
# Out:
#       book_id                                          title  \
# 0           1        The Hunger Games (The Hunger Games, #1)
# 11         12                      Divergent (Divergent, #1)
# 14         17           Catching Fire (The Hunger Games, #2)
# 16         20              Mockingjay (The Hunger Games, #3)
# 2368     2533  The Winner's Curse (The Winner's Trilogy, #1)
# 3077     3318                  Birthmarked (Birthmarked, #1)
# 5642     6423   The Winner's Kiss (The Winner's Trilogy, #3)
# 7162     8476           My Soul to Save (Soul Screamers, #2)
# 9903     9709                     The Hunger Pains: A Parody
# 9904     9713              The Wild Ones (The Wild Ones, #1)
#
#                         authors
# 0           ['Suzanne Collins']
# 11            ['Veronica Roth']
# 14          ['Suzanne Collins']
# 16          ['Suzanne Collins']
# 2368         ['Marie Rutkoski']
# 3077      ["Caragh M. O'Brien"]
# 5642         ['Marie Rutkoski']
# 7162         ['Rachel Vincent']
# 9903  ['[The Harvard Lampoon]']
# 9904  ['[The Harvard Lampoon]']

# %% [markdown]
# Finalmente, hay otros atributos que, si bien no usaremos frecuentemente, sí nos puede interesar dejarlos como están en el dataset. Hablamos de aquellos sobre metadatos de los libros, como son el ISBN o las imágenes de las portadas.

# %% [markdown]
# Podemos obtener información útil de los atributos cuantitativos del dataset.

# %%
books.describe()
# Out:
#        average_rating      book_id        isbn13  original_publication_year  \
# count    10000.000000  10000.00000  9.415000e+03                9979.000000
# mean         4.002191   5000.50000  9.755044e+12                1981.987674
# std          0.254427   2886.89568  4.428619e+11                 152.576665
# min          2.470000      1.00000  1.951703e+08               -1750.000000
# 25%          3.850000   2500.75000  9.780316e+12                1990.000000
# 50%          4.020000   5000.50000  9.780452e+12                2004.000000
# 75%          4.180000   7500.25000  9.780831e+12                2011.000000
# max          4.820000  10000.00000  9.790008e+12                2017.000000
#
#              pages      ratings_1      ratings_2      ratings_3     ratings_4  \
# count  9927.000000   10000.000000   10000.000000   10000.000000  1.000000e+04
# mean    359.419764    1345.040600    3110.885000   11475.893800  1.996570e+04
# std     216.949919    6635.626263    9717.123578   28546.449183  5.144736e+04
# min       0.000000      11.000000      30.000000     323.000000  7.500000e+02
# 25%     250.000000     196.000000     656.000000    3112.000000  5.405750e+03
# 50%     336.000000     391.000000    1163.000000    4894.000000  8.269500e+03
# 75%     424.000000     885.000000    2353.250000    9287.000000  1.602350e+04
# max    5216.000000  456191.000000  436802.000000  793319.000000  1.481305e+06
#
#           ratings_5       work_id  work_ratings_count  work_text_reviews_count
# count  1.000000e+04  1.000000e+04        1.000000e+04             10000.000000
# mean   2.378981e+04  8.646183e+06        5.968732e+04              2919.955300
# std    7.976889e+04  1.175106e+07        1.678038e+05              6124.378132
# min    7.540000e+02  8.700000e+01        5.510000e+03                 3.000000
# 25%    5.334000e+03  1.008841e+06        1.543875e+04               694.000000
# 50%    8.836000e+03  2.719524e+06        2.383250e+04              1402.000000
# 75%    1.730450e+04  1.451775e+07        4.591500e+04              2744.250000
# max    3.011543e+06  5.639960e+07        4.942365e+06            155254.000000

# %% [markdown]
# Comprobamos que el libro que menor número de reviews tiene aun así cuenta con un total de valoraciones que podemos considerar significativo (dispone de 5510 valoraciones). Podemos comprobar con más detalle qué porcentaje de libros cuenta con más de 10000 valoraciones.

# %%
import numpy as np
import matplotlib.pyplot as plt

m = 1
M = 10
paso = 1
num_ratings_percentile = [(i, np.percentile(books['work_ratings_count'], i)) for i in range(m, M + 1, paso)]

# Gráfica para comprobar qué porcentaje de libros tienen menos de 10k valoraciones
plt.plot([x[0] for x in num_ratings_percentile], [x[1] for x in num_ratings_percentile], 'bo-')
plt.axhline(y=10000, color='r', linestyle='--')
plt.xticks(np.arange(m, M + 1, paso))
plt.xlabel('Percentil')
plt.ylabel('Número de valoraciones')
plt.title('Número de valoraciones en los percentiles más bajos')
plt.legend(['Número de valoraciones', 'Límite de 10k valoraciones'])
plt.show()

# %% [markdown]
# Vemos que aproximadamente el 97% de libros cuenta con más de 10000 reseñas. Tenemos un dataset que, en líneas generales, es robusto en cuanto a número de valoraciones por libro, pues la gran mayoría tiene más de 9000 valoraciones según el gráfico. En este sentido, es probable que no tengamos que recortar el dataset de los libros, ya que todos disponen de un número de reviews suficiente como para ser tenidos en cuenta por el sistema recomendador.

# %% [markdown]
# Ahora, nos centraremos en aspectos cualitativos más específicos del dataset.

# %% [markdown]
# Primero vamos a comprobar cuántos libros no disponen de descripción y cuáles son, para, en función de su grado de conocimiento, descartarlos o, por el contrario, añadir con paciencia alguna descripción si son de interés.

# %%
no_description = books[books['description'].isna()].sort_values(by='work_ratings_count')
no_description
# Out:
#                                                 authors  average_rating  \
# 7866                                     ['عمرو سلامة']            3.66
# 7483                                   ['Gayle Forman']            4.24
# 9947                        ['[Justine Korman Fontes]']            4.48
# 9297                                       ['[Amazon]']            3.64
# 7098         ['Ludwig Wittgenstein', 'G.E.M. Anscombe']            4.23
# 8099                                ['Chuck Palahniuk']            3.93
# 9751                               ['[Gerald N. Lund]']            4.30
# 9702              ['[Eugene Bradley Coco', 'Ron Dias]']            4.33
# 7159                         ['Aristotle', 'Joe Sachs']            4.00
# 9625  ['[Warren Ellis', 'Darick Robertson', 'Rodney ...            4.40
# 9541         ['[Patricia M. Scarry', 'Richard Scarry]']            4.28
# 9349                                   ['[John Locke]']            3.82
# 7312                                    ['David Mamet']            3.95
# 9994  ['[Lois Lowry', 'Diane deGroat', 'Diane de Gro...            3.89
# 6760                              ['Kurt Vonnegut Jr.']            3.93
# 6640                                    ['Enid Blyton']            4.28
# 6824                                     ['David Hume']            3.90
# 9406                                 ['[Frank Miller]']            4.10
# 5883                                   ['Dylan Thomas']            4.20
# 8969                                    ['[Jan Brett]']            4.19
# 9156                             ['[Katharine Graham]']            4.13
# 5720              ['Thomas à Kempis', 'William Benham']            4.19
# 5650                                 ['Drew Karpyshyn']            4.25
# 6700                                    ['Oscar Wilde']            3.90
# 8910                                 ['[Jon Krakauer]']            3.97
# 8861                                  ['[A.G. Riddle]']            4.50
# 5525                               ['Ernest Hemingway']            3.80
# 9028                             ['[Ludwig Bemelmans]']            4.27
# 5422                                   ['J.K. Rowling']            4.56
# 8860                                  ['[A.G. Riddle]']            3.93
# 8837            ['[Michael Teitelbaum', 'Sue DiCicco]']            4.32
# 8968                                    ['[Jan Brett]']            4.25
# 9075                               ['[Beverly Cleary]']            3.95
# 5327                                     ['John Keats']            4.24
# 5724                            ['William Shakespeare']            3.71
# 8970                                    ['[Jan Brett]']            4.07
# 6434                ['A.A. Milne', 'Ernest H. Shepard']            4.32
# 5789                                  ['Iris Johansen']            4.07
# 4522                                    ['Matt Ridley']            4.02
# 5253  ['George Eliot', 'Joanna Trollope', 'Hugh Osbo...            3.77
# 5150                              ['Joseph Kesselring']            4.14
# 8543               ['[Robert Sabuda', 'Lewis Carroll]']            4.33
# 3947        ['Plato', 'G.M.A. Grube', 'John M. Cooper']            4.06
# 8545               ['[Robert Sabuda', 'Lewis Carroll]']            4.06
# 3511                  ['Lewis Carroll', 'John Tenniel']            4.22
# 8544               ['[Robert Sabuda', 'Lewis Carroll]']            3.90
# 3165  ['Stephen R. Covey', 'A. Roger Merrill', 'Rebe...            4.06
# 3229                                 ['Jonathan Swift']            4.05
# 2502               ['Benjamin Franklin', 'Lewis Leary']            3.83
# 1638                                      ['Tom Wolfe']            3.81
# 1566  ['William Shakespeare', 'Katherine Duncan-Jones']            4.24
# 1579                                   ['Walt Whitman']            4.12
# 1252                  ['Anonymous', 'Joseph Smith Jr.']            4.37
# 1244      ['Allen Ginsberg', 'William Carlos Williams']            4.14
# 1044           ['Aesop', 'Laura Harris', 'Laura Gibbs']            4.05
# 911                                     ['Jules Verne']            3.84
# 427                                       ['Anonymous']            4.43
#
#       book_id description                                             genres  \
# 7866     9555         NaN                           [nonfiction, philosophy]
# 7483     8971         NaN  [young-adult, romance, fiction, contemporary, ...
# 9947     9818         NaN  [fiction, fantasy, comics, books, romance, cla...
# 9297     7803         NaN                              [history, nonfiction]
# 7098     8390         NaN     [philosophy, nonfiction, classics, psychology]
# 8099     9900         NaN          [fiction, horror, contemporary, thriller]
# 9751     9241         NaN  [historical-fiction, fiction, religion, histor...
# 9702     9120         NaN                       [fiction, fantasy, classics]
# 7159     8472         NaN  [philosophy, classics, nonfiction, history, sc...
# 9625     8880         NaN  [comics, graphic-novels, science-fiction, fict...
# 9541     8665         NaN          [fiction, classics, fantasy, young-adult]
# 9349     7990         NaN  [philosophy, classics, nonfiction, psychology,...
# 7312     8696         NaN                                [fiction, classics]
# 9994     9974         NaN     [fiction, young-adult, classics, contemporary]
# 6760     7921         NaN      [science-fiction, fiction, classics, fantasy]
# 6640     7767         NaN          [fantasy, fiction, classics, young-adult]
# 6824     8011         NaN  [philosophy, nonfiction, classics, psychology,...
# 9406     8214         NaN  [graphic-novels, comics, fiction, crime, myste...
# 5883     6736         NaN                        [poetry, classics, fiction]
# 8969     6518         NaN                       [fiction, classics, fantasy]
# 9156     7239         NaN  [biography, memoir, nonfiction, history, busin...
# 5720     6524         NaN  [religion, christian, classics, nonfiction, sp...
# 5650     6431         NaN                [science-fiction, fiction, fantasy]
# 6700     7838         NaN                                [classics, fiction]
# 8910     6251         NaN  [nonfiction, travel, sports, memoir, biography...
# 8861     6027         NaN  [science-fiction, fiction, thriller, fantasy, ...
# 9702  9.780307e+12           eng                     1992.0  ...       358
# 7159  9.781888e+12           eng                     -330.0  ...       607
# 9625  9.781564e+12           eng                     2001.0  ...       242
# 9541           NaN           eng                     1961.0  ...       312
# 9349  9.781407e+12            de                     1689.0  ...       865
# 7312  9.780802e+12           eng                     1983.0  ...       801
# 9994  9.780553e+12            et                     1978.0  ...       603
# 6760           NaN           eng                     1962.0  ...       510
# 6640  9.781405e+12           eng                     1991.0  ...       421
# 6824  9.781421e+12           eng                     1748.0  ...       809
# 9406  9.781593e+12           eng                     1994.0  ...       432
# 5883  9.780811e+12           eng                     1952.0  ...       354
# 8969           NaN           eng                     2009.0  ...       320
# 9156  9.780376e+12           eng                     1997.0  ...       516
# 5720  9.780376e+12           eng                     1418.0  ...       653
# 5650  9.780345e+12           eng                     2006.0  ...       428
# 6700  9.780141e+12           eng                     1893.0  ...       594
# 8910  9.780385e+12            de                     1990.0  ...       472
# 8861  9.781422e+12           eng                     2002.0  ...       303
# 5525  9.780685e+12           eng                     1925.0  ...      1086
# 9028  9.780670e+12           eng                     1956.0  ...       479
# 5422  9.781855e+12           eng                     2003.0  ...       199
# 8860           NaN           eng                     2014.0  ...       886
# 8837  9.780736e+12           eng                     1986.0  ...       621
# 8968  9.780750e+12           eng                     1997.0  ...       517
# 9075  9.780591e+12            es                     1970.0  ...       745
# 5327  9.780680e+12           eng                     1820.0  ...       581
# 5724  9.780672e+12           eng                     1589.0  ...      1848
# 8970  9.780061e+12           eng                     2004.0  ...       928
# 6434  9.780525e+12           eng                     1924.0  ...       472
# 5789  9.780341e+12           eng                     1998.0  ...       629
# 4522  9.780061e+12           eng                     1999.0  ...       777
# 5253  9.780376e+12           eng                     1859.0  ...      1475
# 5150  9.780857e+12           eng                     1939.0  ...       764
# 8543  9.780690e+12           eng                     2003.0  ...       521
# 3947  9.780872e+12           eng                     -400.0  ...      1001
# 8545  9.780451e+12           eng                     2008.0  ...      1137
# 3511  9.781435e+12           eng                     1865.0  ...       888
# 8544           NaN           eng                     2011.0  ...      1773
# 3165  9.780685e+12           eng                     1993.0  ...      1034
# 3229  9.781606e+12           eng                     1729.0  ...      1391
# 2502  9.780743e+12           eng                     1791.0  ...      2925
# 1638  9.780553e+12           eng                     1987.0  ...      4001
# 1566  9.781903e+12           eng                     1592.0  ...      1890
# 1579  9.781417e+12           eng                     1855.0  ...      3015
# 1252  9.780968e+12           eng                     1830.0  ...      2468
# 1244  9.780873e+12           eng                     1956.0  ...      3203
# 1044  9.780193e+12           eng                     -560.0  ...      3717
# 911   9.780553e+12           eng                     1864.0  ...      6342
# 427            NaN           eng                     1611.0  ...      6802
#
#       ratings_3 ratings_4  ratings_5  \
# 7866       2179      2610       2156
# 7483       1245      2462       4273
# 9947       1121      1627       6287
# 9297       1810      2292       3721
# 7098       1389      2869       5198
# 8099       2047      3302       3898
# 9751       1484      3732       5164
# 9702       1704      2158       6277
# 7159       2377      3299       4181
# 9625       1092      3134       6424
# 9541       2095      2748       6234
# 9702              ['[Eugene Bradley Coco', 'Ron Dias]']
# 7159                         ['Aristotle', 'Joe Sachs']
# 9625  ['[Warren Ellis', 'Darick Robertson', 'Rodney ...
# 9541         ['[Patricia M. Scarry', 'Richard Scarry]']
# 9349                                   ['[John Locke]']
# 7312                                    ['David Mamet']
# 9994  ['[Lois Lowry', 'Diane deGroat', 'Diane de Gro...
# 6760                              ['Kurt Vonnegut Jr.']
# 6640                                    ['Enid Blyton']
# 6824                                     ['David Hume']
# 9406                                 ['[Frank Miller]']
# 5883                                   ['Dylan Thomas']
# 8969                                    ['[Jan Brett]']
# 9156                             ['[Katharine Graham]']
# 5720              ['Thomas à Kempis', 'William Benham']
# 5650                                 ['Drew Karpyshyn']
# 6700                                    ['Oscar Wilde']
# 8910                                 ['[Jon Krakauer]']
# 8861                                  ['[A.G. Riddle]']
# 5525                               ['Ernest Hemingway']
# 9028                             ['[Ludwig Bemelmans]']
# 5422                                   ['J.K. Rowling']
# 8860                                  ['[A.G. Riddle]']
# 8837            ['[Michael Teitelbaum', 'Sue DiCicco]']
# 8968                                    ['[Jan Brett]']
# 9075                               ['[Beverly Cleary]']
# 5327                                     ['John Keats']
# 5724                            ['William Shakespeare']
# 8970                                    ['[Jan Brett]']
# 6434                ['A.A. Milne', 'Ernest H. Shepard']
# 5789                                  ['Iris Johansen']
# 4522                                    ['Matt Ridley']
# 5253  ['George Eliot', 'Joanna Trollope', 'Hugh Osbo...
# 5150                              ['Joseph Kesselring']
# 8543               ['[Robert Sabuda', 'Lewis Carroll]']
# 3947        ['Plato', 'G.M.A. Grube', 'John M. Cooper']
# 8545               ['[Robert Sabuda', 'Lewis Carroll]']
# 3511                  ['Lewis Carroll', 'John Tenniel']
# 8544               ['[Robert Sabuda', 'Lewis Carroll]']
# 3165  ['Stephen R. Covey', 'A. Roger Merrill', 'Rebe...
# 3229                                 ['Jonathan Swift']
# 2502               ['Benjamin Franklin', 'Lewis Leary']
# 1638                                      ['Tom Wolfe']
# 1566  ['William Shakespeare', 'Katherine Duncan-Jones']
# 1579                                   ['Walt Whitman']
# 1252                  ['Anonymous', 'Joseph Smith Jr.']
# 1244      ['Allen Ginsberg', 'William Carlos Williams']
# 1044           ['Aesop', 'Laura Harris', 'Laura Gibbs']
# 911                                     ['Jules Verne']
# 427                                       ['Anonymous']
#
# [57 rows x 24 columns]

# %% [markdown]
# Después de comprobar por encima este conjunto de libros, llevamos a cabo algunas transformaciones del dataset.
#
# Eliminamos el primer libro, poco conocido y sin descripción disponible en la red. También la *Guía de Usuario de Kindle*, la cual no es de mayor interés.

# %%
books = books.drop([7866, 9297]) # Elimina dichos libros

# %% [markdown]
# El resto son libros con un importante número de valoraciones como para ser descartados, entre los que se incluyen históricas obras filosóficas y clásicos de la literatura. Podemos añadir manualmente (no son tantas sin completar) o mediante alguna utilidad/API las descripciones que faltan.

# %%
# Potencial código para ir añadiendo las descripciones de dichos libros

# %% [markdown]
# También nos interesa conocer qué entradas del dataset hacen referencia a una colección de libros de la misma saga, pues sus títulos ya son considerados como libros por separado en el dataset.
#
# A la hora de recomendar, se tendrá que decidir si se opta por incluir también las colecciones como obras aparte (englobando los libros de una misma saga) o son descartados por su redundancia, además del hecho de que sus sinopsis, en algunos casos, conciernen al producto como boxset más que como serie literaria.

# %%
books_collection = books[books['title'].str.contains('Collection')]
books_collection
# Out:
#                                          authors  average_rating  book_id  \
# 691   ['Laura Ingalls Wilder', 'Garth Williams']            4.33      740
# 941                          ['Chelsea Handler']            3.79     1007
# 976                            ['Veronica Roth']            4.10     1045
# 1520                         ['Stephenie Meyer']            4.31     1619
# 1899                         ['Stephenie Meyer']            3.78     2021
# 1969           ['J.K. Rowling', 'Mary GrandPré']            4.66     2101
# 2876                           ['Richelle Mead']            4.61     3095
# 3457                            ['J.K. Rowling']            4.73     3753
# 4068                          ['Bill Watterson']            4.75     4483
# 4670                          ['Bill Watterson']            4.68     5207
# 5479                           ['Veronica Roth']            4.56     6214
# 5593                          ['Bill Watterson']            4.74     6361
# 6260                          ['Bill Watterson']            4.71     7254
# 7483                            ['Gayle Forman']            4.24     8971
# 9811   ['[Juan Gabriel Vásquez', 'Anne McLean]']            3.77     9426
#
#                                             description  \
# 691   This nine-book paperback box set of the classi...
# 941   You've either done it or know someone who has:...
# 976   Two years before Beatrice Prior made her choic...
# 1520  This stunning set, complete with five editions...
# 1899  Deeply romantic and extraordinarily suspensefu...
# 1969  The exciting tales of Harry Potter, the young ...
# 2876  Tear into the utterly addictive Vampire Academ...
# 3457  Six years of magic, adventure, and mystery mak...
# 4068  When cartoonist Bill Watterson announced that ...
# 4670  Zounds! Spaceman Spiff, Stupendous Man, the fe...
# 5479  Contains the complete text of Veronica Roth's ...
# 5593  In the world that Calvin and his stuffed tiger...
# 6260  Homicidal Psycho Jungle Cat chronicles the mul...
# 7483                                                NaN
# 9811  Juan Gabriel Vásquez has been hailed not only ...
#
#                                                  genres  \
# 691   [classics, historical-fiction, fiction, young-...
# 941          [nonfiction, memoir, biography, chick-lit]
# 976   [young-adult, fiction, science-fiction, fantas...
# 1520  [fantasy, young-adult, romance, paranormal, fi...
# 1899  [young-adult, fantasy, romance, paranormal, fi...
# 1969          [fantasy, young-adult, fiction, classics]
# 2876  [young-adult, fantasy, paranormal, romance, fi...
# 3457          [fantasy, fiction, young-adult, classics]
# 4068                  [comics, graphic-novels, fiction]
# 4670                  [comics, fiction, graphic-novels]
# 5479  [young-adult, fiction, science-fiction, romanc...
# 5593                  [comics, fiction, graphic-novels]
# 6260                  [comics, fiction, graphic-novels]
# 7483  [young-adult, romance, fiction, contemporary, ...
# 9811  [fiction, historical-fiction, contemporary, my...
#
#                                               image_url        isbn  \
# 691   https://s.gr-assets.com/assets/nophoto/book/11...    60529962
# 941   https://images.gr-assets.com/books/1388631721m...  1582346186
# 976   https://images.gr-assets.com/books/1393687572m...    62285688
# 1520  https://s.gr-assets.com/assets/nophoto/book/11...  031613290X
# 976   Four: A Divergent Story Collection (Divergent,...  25457412
# 1520  The Twilight Saga Complete Collection  (Twilig...  14194990
# 1899           The Twilight Collection (Twilight, #1-3)   3187048
# 1969  The Harry Potter Collection 1-4 (Harry Potter,...   5994366
# 2876  Vampire Academy Collection (Vampire Academy, #...  10954714
# 3457       Harry Potter Collection (Harry Potter, #1-6)  21457570
# 4068  It's a Magical World: A Calvin and Hobbes Coll...     25601
# 4670  The Days Are Just Packed: A Calvin and Hobbes ...    946589
# 5479  The Divergent Series 2-Book Collection (Diverg...  21431022
# 5593  There's Treasure Everywhere: A Calvin and Hobb...    170846
# 6260  Homicidal Psycho Jungle Cat: A Calvin and Hobb...   2369970
# 7483             If I Stay Collection (If I Stay, #1-2)  41164642
# 9811   Maid for the Billionaire (Legacy Collection, #1)  16166069
#
#       work_ratings_count work_text_reviews_count  \
# 691               128880                    2016
# 941                89257                    6051
# 976               116243                    9213
# 1520               57789                     335
# 1899               42383                    1127
# 1969               44842                     265
# 2876               30509                     182
# 3457               26274                     882
# 4068               23429                     264
# 4670               20374                     228
# 5479               14038                     255
# 5593               17285                     149
# 6260               15729                     289
# 7483                8428                     509
# 9811               16816                     947
#
#                                        authors_2
# 691   ['Laura Ingalls Wilder', 'Garth Williams']
# 941                          ['Chelsea Handler']
# 976                            ['Veronica Roth']
# 1520                         ['Stephenie Meyer']
# 1899                         ['Stephenie Meyer']
# 1969           ['J.K. Rowling', 'Mary GrandPré']
# 2876                           ['Richelle Mead']
# 3457                            ['J.K. Rowling']
# 4068                          ['Bill Watterson']
# 4670                          ['Bill Watterson']
# 5479                           ['Veronica Roth']
# 5593                          ['Bill Watterson']
# 6260                          ['Bill Watterson']
# 7483                            ['Gayle Forman']
# 9811   ['[Juan Gabriel Vásquez', 'Anne McLean]']
#
# [15 rows x 24 columns]

# %% [markdown]
# Por otro lado, también contabilizamos aquellos libros en cuya descripción encontramos otro tipo de datos ajenos a una sinopsis, como es la palabra ISBN. Esto es un dato que nos puede interesar de cara a la extracción de información a partir de NLP.

# %%
books_desc_isbn = books[(books['description'].notna()) & (books['description'].str.contains('ISBN'))]
print(len(books_desc_isbn))
books_desc_isbn.head()
# Out:
# 162
#                              authors  average_rating  book_id  \
# 4            ['F. Scott Fitzgerald']            3.89        5
# 9                    ['Jane Austen']            4.24       10
# 13  ['Stieg Larsson', 'Reg Keeland']            4.11       16
# 22                     ['Dan Brown']            3.79       26
# 36                  ['Rick Riordan']            4.23       41
#
#                                           description  \
# 4   Alternate Cover Edition ISBN: 0743273567 (ISBN...
# 9   Alternate cover edition of ISBN 9780679783268S...
# 13  Harriet Vanger, a scion of one of Sweden’s wea...
# 22  ISBN 9780307277671 moved to this edition.While...
# 36  Alternate cover for this ISBN can be found her...
#
#                                                genres  \
# 4    [classics, fiction, historical-fiction, romance]
# 9    [classics, fiction, romance, historical-fiction]
# 13  [fiction, mystery, suspense, contemporary, thr...
# 22  [fiction, mystery, thriller, suspense, histori...
# 36                    [fantasy, young-adult, fiction]
#
#                                             image_url       isbn  \
# 4   https://images.gr-assets.com/books/1490528560m...  743273567
# 9   https://images.gr-assets.com/books/1320399351m...  679783261
# 13  https://images.gr-assets.com/books/1327868566m...  307269752
# 22  https://images.gr-assets.com/books/1303252999m...  307277674
# 36  https://images.gr-assets.com/books/1400602609m...  786838655
#
#           isbn13 language_code  original_publication_year  ... ratings_2  \
# 4   9.780743e+12           eng                     1925.0  ...    197621
# 9   9.780680e+12           eng                     1813.0  ...     86485
# 13  9.780307e+12           eng                     2005.0  ...     86051
# 22  9.780307e+12           eng                     2003.0  ...    126493
# 36  9.780787e+12           eng                     2005.0  ...     48294
#
#     ratings_3 ratings_4  ratings_5  \
# 4      606158    936012     947718
# 9      284852    609755    1155673
# 13     285413    667485     836050
# 22     340790    539277     479387
# 36     219638    435514     689365
#
#                                       small_image_url  \
# 4   https://images.gr-assets.com/books/1490528560s...
# 9   https://images.gr-assets.com/books/1320399351s...
# 13  https://images.gr-assets.com/books/1327868566s...
# 22  https://images.gr-assets.com/books/1303252999s...
# 36  https://images.gr-assets.com/books/1400602609s...
#
#                                                 title  work_id  \
# 4                                    The Great Gatsby   245494
# 9                                 Pride and Prejudice  3060926
# 13   The Girl with the Dragon Tattoo (Millennium, #1)  1708725
# 22             The Da Vinci Code (Robert Langdon, #2)  2982101
# 36  The Lightning Thief (Percy Jackson and the Oly...  3346751
#
#     work_ratings_count work_text_reviews_count  \
# 4              2773745                   51992
# 9              2191465                   49152
# 13             1929834                   62543
# 22             1557292                   41560
# 36             1411114                   46006
#
#                            authors_2
# 4            ['F. Scott Fitzgerald']
# 9                    ['Jane Austen']
# 13  ['Stieg Larsson', 'Reg Keeland']
# 22                     ['Dan Brown']
# 36                  ['Rick Riordan']
#
# [5 rows x 24 columns]

# %% [markdown]
# Otro detalle que podemos comprobar es el atributo `language_code` de los libros del dataset. Este se refiere al código del idioma en que está el libro, tratado como producto, y que puede afectar a la hora de comprender las sinopsis a partir de un tratamiento por NLP.

# %%
books.groupby('language_code').count()
# Out:
#                authors  average_rating  book_id  description  genres  \
# language_code
# af                   1               1        1            1       1
# ara                 63              63       63           63      63
# cs                   2               2        2            2       2
# da                   7               7        7            7       7
# dan                  3               3        3            3       3
# de                  33              33       33           31      33
# eng               9679            9679     9679         9628    9679
# es                  21              21       21           20      21
# et                   1               1        1            0       1
# fi                   1               1        1            1       1
# fil                  2               2        2            2       2
# fr                  18              18       18           18      18
# fre                 25              25       25           25      25
# ger                 13              13       13           13      13
# hu                   1               1        1            1       1
# id                   1               1        1            1       1
# ind                 21              21       21           21      21
# is                   1               1        1            1       1
# it                  13              13       13           13      13
# ita                  2               2        2            2       2
# jpn                  7               7        7            7       7
# lt                   1               1        1            1       1
# ms                   3               3        3            3       3
# mt                   3               3        3            3       3
# mul                  1               1        1            1       1
# nl                   7               7        7            7       7
# no                   1               1        1            1       1
# nor                  3               3        3            3       3
# per                  7               7        7            7       7
# pl                   6               6        6            6       6
# pol                  6               6        6            6       6
# por                  6               6        6            6       6
# ro                   7               7        7            7       7
# rum                  1               1        1            1       1
# rus                  1               1        1            1       1
# spa                 20              20       20           20      20
# sv                   6               6        6            6       6
# swe                  1               1        1            1       1
# tur                  1               1        1            1       1
# vie                  1               1        1            1       1
# zh                   1               1        1            1       1
#
#                image_url  isbn  isbn13  original_publication_year  \
# language_code
# af                     1     1       1                          1
# ara                   63    11      33                         62
# cs                     2     2       2                          2
# da                     7     6       6                          7
# dan                    3     3       3                          3
# de                    33    29      29                         33
# eng                 9679  9059    9144                       9659
# es                    21    21      21                         21
# et                     1     1       1                          1
# fi                     1     1       1                          1
# fil                    2     1       2                          2
# fr                    18    18      18                         18
# fre                   25    24      24                         25
# ger                   13    13      13                         13
# hu                     1     1       1                          1
# id                     1     1       1                          1
# ind                   21    12      16                         21
# is                     1     1       1                          1
# it                    13    12      12                         13
# ita                    2     2       2                          2
# jpn                    7     6       7                          7
# lt                     1     1       1                          1
# ms                     3     3       3                          3
# mt                     3     3       3                          3
# mul                    1     1       1                          1
# nl                     7     6       7                          7
# no                     1     1       1                          1
# nor                    3     1       3                          3
# per                    7     5       2                          7
# pl                     6     6       6                          6
# pol                    6     5       5                          6
# por                    6     5       6                          6
# ro                     7     7       7                          7
# rum                    1     1       1                          1
# rus                    1     1       1                          1
# spa                   20    19      19                         20
# sv                     6     6       6                          6
# swe                    1     1       1                          1
# tur                    1     1       1                          1
# vie                    1     1       1                          1
# zh                     1     1       1                          1
#
#                original_title  ...  ratings_2  ratings_3  ratings_4  \
# language_code                  ...
# af                          1  ...          1          1          1
# ara                        57  ...         63         63         63
# cs                          2  ...          2          2          2
# da                          7  ...          7          7          7
# dan                         3  ...          3          3          3
# de                         27  ...         33         33         33
# eng                      9118  ...       9679       9679       9679
# es                         19  ...         21         21         21
# et                          1  ...          1          1          1
# fi                          1  ...          1          1          1
# fil                         1  ...          2          2          2
# fr                         17  ...         18         18         18
# fre                        23  ...         25         25         25
# ger                        13  ...         13         13         13
# hu                          1  ...          1          1          1
# id                          1  ...          1          1          1
# ind                        21  ...         21         21         21
# is                          1  ...          1          1          1
# it                         12  ...         13         13         13
# ita                         2  ...          2          2          2
# jpn                         7  ...          7          7          7
# lt                          1  ...          1          1          1
# ms                          3  ...          3          3          3
# mt                          3  ...          3          3          3
# mul                         0  ...          1          1          1
# nl                          7  ...          7          7          7
# no                          1  ...          1          1          1
# nor                         3  ...          3          3          3
# per                         7  ...          7          7          7
# pl                          4  ...          6          6          6
# pol                         6  ...          6          6          6
# por                         6  ...          6          6          6
# ro                          7  ...          7          7          7
# rum                         1  ...          1          1          1
# rus                         1  ...          1          1          1
# spa                        20  ...         20         20         20
# sv                          6  ...          6          6          6
# swe                         1  ...          1          1          1
# tur                         1  ...          1          1          1
# vie                         1  ...          1          1          1
# zh                          0  ...          1          1          1
#
#                ratings_5  small_image_url  title  work_id  work_ratings_count  \
# language_code
# af                     1                1      1        1                   1
# ara                   63               63     63       63                  63
# cs                     2                2      2        2                   2
# da                     7                7      7        7                   7
# dan                    3                3      3        3                   3
# de                    33               33     33       33                  33
# eng                 9679             9679   9679     9679                9679
# es                    21               21     21       21                  21
# et                     1                1      1        1                   1
# fi                     1                1      1        1                   1
# fil                    2                2      2        2                   2
# fr                    18               18     18       18                  18
# fre                   25               25     25       25                  25
# ger                   13               13     13       13                  13
# hu                     1                1      1        1                   1
# id                     1                1      1        1                   1
# ind                   21               21     21       21                  21
# is                     1                1      1        1                   1
# it                    13               13     13       13                  13
# ita                    2                2      2        2                   2
# jpn                    7                7      7        7                   7
# lt                     1                1      1        1                   1
# ms                     3                3      3        3                   3
# mt                     3                3      3        3                   3
# mul                    1                1      1        1                   1
# nl                     7                7      7        7                   7
# no                     1                1      1        1                   1
# nor                    3                3      3        3                   3
# per                    7                7      7        7                   7
# pl                     6                6      6        6                   6
# pol                    6                6      6        6                   6
# por                    6                6      6        6                   6
# ro                     7                7      7        7                   7
# rum                    1                1      1        1                   1
# rus                    1                1      1        1                   1
# spa                   20               20     20       20                  20
# sv                     6                6      6        6                   6
# swe                    1                1      1        1                   1
# tur                    1                1      1        1                   1
# vie                    1                1      1        1                   1
# zh                     1                1      1        1                   1
#
#                work_text_reviews_count  authors_2
# language_code
# af                                   1          1
# ara                                 63         63
# cs                                   2          2
# da                                   7          7
# dan                                  3          3
# de                                  33         33
# eng                               9679       9679
# es                                  21         21
# et                                   1          1
# fi                                   1          1
# fil                                  2          2
# fr                                  18         18
# fre                                 25         25
# ger                                 13         13
# hu                                   1          1
# id                                   1          1
# ind                                 21         21
# is                                   1          1
# it                                  13         13
# ita                                  2          2
# jpn                                  7          7
# lt                                   1          1
# ms                                   3          3
# mt                                   3          3
# mul                                  1          1
# nl                                   7          7
# no                                   1          1
# nor                                  3          3
# per                                  7          7
# pl                                   6          6
# pol                                  6          6
# por                                  6          6
# ro                                   7          7
# rum                                  1          1
# rus                                  1          1
# spa                                 20         20
# sv                                   6          6
# swe                                  1          1
# tur                                  1          1
# vie                                  1          1
# zh                                   1          1
#
# [41 rows x 23 columns]

# %% [markdown]
# Como vemos, hay una clara predominancia de libros en inglés. Sin embargo, también destaca el total de libros en árabe, español, alemán o francés. Comprobemos si, en efecto, estos libros disponen de una descripción en dichos idiomas.

# %%
def books_lang(language_code):
    """
    Retorna un dataframe con los libros del lenguaje indicado
    """
    return books[books['language_code'] == language_code]

books_arabic = books_lang('ara')
books_arabic.head()
# Out:
#                                        authors  average_rating  book_id  \
# 1286                             ['أحمد مراد']            3.80     1372
# 1386  ['أحلام مستغانمي', 'Ahlam Mosteghanemi']            3.72     1475
# 1547                             ['أحمد مراد']            4.09     1647
# 1678                             ['محمد صادق']            3.82     1787
# 1817                   ['أثير عبدالله النشمي']            3.67     1933
#
#                                             description  \
# 1286  بعد خمس سنوات من العُزلة الاختيارية يستأنف د. ...
# 1386  ما من قصة حب إلا و تبدأ بحركة موسيقية ، قائد ا...
# 1547  "للمرة الثانية بعد "فيرتيجو" يتّخذ أحمد مراد م...
# 1678  تأخذنا رواية (هيبتا) إلي ذلك العالم الذي أهلكه...
# 1817  "أجلس اليوم إلى جوارك، أندب أحلامي الحمقى.. غا...
#
#                                                  genres  \
# 1286  [fiction, horror, mystery, fantasy, psychology...
# 1386                                 [romance, fiction]
# 1547  [fiction, crime, thriller, contemporary, fantasy]
# 1678       [romance, fiction, philosophy, contemporary]
# 1817                                 [romance, fiction]
#
#                                               image_url isbn        isbn13  \
# 1286  https://images.gr-assets.com/books/1485105416m...  NaN  9.789771e+12
# 1386  https://images.gr-assets.com/books/1351004560m...  NaN  9.789953e+12
# 1547  https://s.gr-assets.com/assets/nophoto/book/11...  NaN           NaN
# 1678  https://images.gr-assets.com/books/1403045796m...  NaN           NaN
# 1817  https://s.gr-assets.com/assets/nophoto/book/11...  NaN  9.789954e+12
#
#      language_code  original_publication_year  ... ratings_2  ratings_3  \
# 1286           ara                     2012.0  ...      4687      11444
# 1386           ara                     2012.0  ...      5535      11642
# 1547           ara                     2010.0  ...      2050       7402
# 1678           ara                     2014.0  ...      4135       8052
# 1817           ara                     2010.0  ...      4620       8914
#
#      ratings_4  ratings_5                                    small_image_url  \
# 1286     16996      18433  https://images.gr-assets.com/books/1485105416s...
# 1386     13878      17877  https://images.gr-assets.com/books/1351004560s...
# 1547     16743      18418  https://s.gr-assets.com/assets/nophoto/book/50...
# 1678     11237      16988  https://images.gr-assets.com/books/1403045796s...
# 1817     10505      14755  https://s.gr-assets.com/assets/nophoto/book/50...
#
#                       title   work_id  work_ratings_count  \
# 1286           الفيل الأزرق  21801712               54340
# 1386         الأسود يليق بك  21881449               52255
# 1547             تراب الماس  10406860               45608
# 1678                  هيبتا  28155746               43298
# 1817  أحببتك أكثر مما ينبغي   7379975               42357
#
#      work_text_reviews_count                                 authors_2
# 1286                    5771                             ['أحمد مراد']
# 1386                    5459  ['أحلام مستغانمي', 'Ahlam Mosteghanemi']
# 1547                    4027                             ['أحمد مراد']
# 1678                    5680                             ['محمد صادق']
# 1817                    4898                   ['أثير عبدالله النشمي']
#
# [5 rows x 24 columns]

# %%
books_spanish = pd.concat([books_lang('spa'), books_lang('es')])
print(len(books_spanish))
books_spanish.head(10)
# Out:
# 41
#                                                 authors  average_rating  \
# 513                                    ['Stephen King']            3.65
# 860         ['Stephen King', 'Bettina Blanch Tyroller']            3.79
# 1690  ['Philip K. Dick', 'David Alabort', 'Manuel Es...            4.10
# 1707                                  ['Clive Cussler']            3.95
# 3223                                      ['Anne Rice']            3.73
# 3432                                 ['Ernesto Sabato']            4.04
# 3456                                ['Agatha Christie']            4.07
# 3797                             ['Ildefonso Falcones']            4.05
# 4088                                 ['Roberto Bolaño']            4.20
# 4168                                 ['Isabel Allende']            4.07
#
#       book_id                                        description  \
# 513       556  Outside a peaceful town in central Maine, a mo...
# 860       915  Ralph Roberts, a sus setenta años y tras la mu...
# 4088  https://images.gr-assets.com/books/1412644327s...
# 4168  https://images.gr-assets.com/books/1316284499s...
#
#                                         title  work_id  work_ratings_count  \
# 513                                      Cujo   996156              167044
# 860                                  Insomnia  1590722              109444
# 1690                                     Ubik    62929               58063
# 1707                  Sahara (Dirk Pitt, #11)  2467487               48850
# 3223  Pandora (New Tales of the Vampires, #1)  2926330               37086
# 3432                                 El túnel     5793               28256
# 3456   Poirot Investiga (Hércules Poirot, #3)  1952109               29408
# 3797                      La catedral del mar  2731326               25313
# 4088                                     2666  3294830               22318
# 4168                                    Paula   419162               23529
#
#      work_text_reviews_count  \
# 513                     2832
# 860                     2296
# 1690                    2957
# 1707                     745
# 3223                     672
# 3432                    1618
# 3456                     779
# 3797                    1387
# 4088                    2930
# 4168                    1447
#
#                                               authors_2
# 513                                    ['Stephen King']
# 860         ['Stephen King', 'Bettina Blanch Tyroller']
# 1690  ['Philip K. Dick', 'David Alabort', 'Manuel Es...
# 1707                                  ['Clive Cussler']
# 3223                                      ['Anne Rice']
# 3432                                 ['Ernesto Sabato']
# 3456                                ['Agatha Christie']
# 3797                             ['Ildefonso Falcones']
# 4088                                 ['Roberto Bolaño']
# 4168                                 ['Isabel Allende']
#
# [10 rows x 24 columns]

# %%
books_french = pd.concat([books_lang('fre'), books_lang('fr')])
print(len(books_french))
books_french.head(10)
# Out:
# 43
#                                           authors  average_rating  book_id  \
# 534             ['Stephen King', 'Marie Milpois']            3.72      578
# 738          ['Irvine Welsh', 'Eric Lindor Fall']            4.07      788
# 767   ['Stephen King', 'William Olivier Desmond']            3.59      818
# 1004           ['Stephen King', 'Dominique Dill']            3.81     1075
# 2233                          ['Marjane Satrapi']            4.27     2386
# 2521                       ['Hunter S. Thompson']            4.00     2703
# 2652                              ['Joël Dicker']            3.94     2847
# 4411      ['René Goscinny', 'Jean-Jacques Sempé']            4.13     4902
# 4564                      ['Sui Ishida', '石田 スイ']            4.43     5074
# 5295           ['Arthur C. Clarke', 'Gentry Lee']            3.66     5982
#
#                                             description  \
# 534   Master storyteller Stephen King presents the c...
# 738   The bestselling novel by Irvine Welsh that pro...
# 767   Au coeur de la forêt de Derry, quatre amis d'e...
# 1004  Suspected of killing Vera Donovan, her wealthy...
# 2233  Première bande dessinée issue de l'Iran, Perse...
# 2521  Au début des années soixante, Thompson, alors ...
# 2652  À New York, au printemps 2008, alors que l’Amé...
# 4411  La maîtresse est inquiète, le photographe s'ép...
# 4564  À Tokyo, sévissent des goules, monstres cannib...
# 5295  70 years after the events of Rendezvous with R...
#
#                                                  genres  \
# 534   [horror, fiction, thriller, fantasy, paranorma...
# 738   [fiction, contemporary, classics, thriller, my...
# 767   [horror, fiction, science-fiction, thriller, f...
# 1004  [horror, fiction, thriller, mystery, suspense,...
# 2233  [graphic-novels, comics, nonfiction, memoir, h...
# 2521  [nonfiction, history, memoir, biography, crime...
# 2652  [fiction, mystery, thriller, crime, contempora...
# 4411                   [fiction, classics, young-adult]
# 4564               46108                     940
# 5295               17781                     475
#
#                                         authors_2
# 534             ['Stephen King', 'Marie Milpois']
# 738          ['Irvine Welsh', 'Eric Lindor Fall']
# 767   ['Stephen King', 'William Olivier Desmond']
# 1004           ['Stephen King', 'Dominique Dill']
# 2233                          ['Marjane Satrapi']
# 2521                       ['Hunter S. Thompson']
# 2652                              ['Joël Dicker']
# 4411      ['René Goscinny', 'Jean-Jacques Sempé']
# 4564                      ['Sui Ishida', '石田 スイ']
# 5295           ['Arthur C. Clarke', 'Gentry Lee']
#
# [10 rows x 24 columns]

# %% [markdown]
# Como vemos, sí hay buena parte de los libros con esos códigos de idioma que presentan una descripción en dicho idioma. Se tendrá que tener en cuenta en el futuro análisis por comprensión de lenguaje natural.

# %% [markdown]
# ### <a id="ratings"></a> Análisis del dataset de ratings de usuarios

# %%
user_ratings = pd.read_csv(path + 'ratings.csv')

# %% [markdown]
# Comprobamos los detalles del dataset, esta vez para las valoraciones de usuarios.

# %%
user_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5976479 entries, 0 to 5976478
# Data columns (total 3 columns):
#  #   Column   Dtype
# ---  ------   -----
#  0   user_id  int64
#  1   book_id  int64
#  2   rating   int64
# dtypes: int64(3)
# memory usage: 136.8 MB

# %% [markdown]
# En este dataset encontramos tres columnas:
#
# - `user_id`: el identificador del usuario de *GoodReads*
# - `book_id`: el identificador del libro en el dataset de los libros
# - `rating`: valoración del 1 al 5 que el usuario dio a dicho libro
#
# Si bien el sistema recomendador será *Content-Based*, este dataset puede ser útil a la hora de comprender los gustos de los usuarios basándonos en su historial de lecturas y las valoraciones dadas. En ese caso, nos interesarán aquellos usuarios con un número significativo de ratings.

# %%
user_ratings.head()
# Out:
#    user_id  book_id  rating
# 0        1      258       5
# 1        2     4081       4
# 2        2      260       5
# 3        2     9296       5
# 4        2     2318       3

# %% [markdown]
# Incluimos un análisis generalizado del dataset.

# %%
user_ratings.describe()
# Out:
#             user_id       book_id        rating
# count  5.976479e+06  5.976479e+06  5.976479e+06
# mean   2.622446e+04  2.006477e+03  3.919866e+00
# std    1.541323e+04  2.468499e+03  9.910868e-01
# min    1.000000e+00  1.000000e+00  1.000000e+00
# 25%    1.281300e+04  1.980000e+02  3.000000e+00
# 50%    2.593800e+04  8.850000e+02  4.000000e+00
# 75%    3.950900e+04  2.973000e+03  5.000000e+00
# max    5.342400e+04  1.000000e+04  5.000000e+00

# %% [markdown]
# Como comprobamos, la nota media de los libros es de 3.92, un valor que nos puede dar algunas indicaciones sobre el dataset de libros. Al ser una nota relativamente generosa, se puede llegar a la conclusión de que los libros del dataset son, en general, populares y bien valorados entre la población. A priori, esto no es algo negativo, ya que al ser un dataset más o menos extenso, hay la suficiente variedad de libros como para dar una recomendación que se ajuste a las preferencias del usuario.
#
# No obstante, puede ocurrir que obras menos conocidas se vean perjudicadas en el sentido de que no sean recomendadas lo suficiente como para llegar a un público que ya conoce de antemano los libros más populares y busca algo más selecto (diamantes en bruto). Esto enlaza con otra de las conclusiones que podemos extraer de este dataset.
#
# Podría ocurrir que la muestra de usuarios esté algo sesgada a la hora de valorar los libros que lee, dando con muchísima más frecuencia notas entre 4 y 5 a libros que, en teoría, se corresponderían más con un 3, por ejemplo. Por supuesto, cada usuario da su valoración libremente, pero cuando se trata de un fenómeno acumulado, es un dato a tener en cuenta. Para esto último, comprobemos mediante un histograma cómo se distibuyen las valoraciones entre los usuarios.

# %%
# Histograma de las valoraciones de los usuarios
plt.hist(user_ratings['rating'])
plt.xlabel('Valoraciones de usuarios (1-5)')
plt.ylabel('Número de valoraciones')
plt.title('Distibución de las valoraciones de los usuarios')
plt.show()

# %% [markdown]
# El histograma nos confirma que la gran mayoría de libros reciben valoraciones de 4 o 5, seguido de una importante cantidad de valoraciones con un 3. Hay una asimetría a la izquierda que, si bien puede ser lógica por los libros incluidos en el dataset, no debemos perder de vista.

# %% [markdown]
# Ahora comprobemos el número de valoraciones por usuario para hacernos una idea de cuántos o cuáles usuarios deben ser tenidos en cuenta en caso de incorporar un mecanismo de *Collaborative Filtering*.

# %%
# Agrupar por usuario y contar el número de valoraciones que ha hecho cada uno
users_n_ratings = user_ratings.groupby('user_id').count()
users_n_ratings.describe()
# Out:
#             book_id        rating
# count  53424.000000  53424.000000
# mean     111.868804    111.868804
# std       26.071224     26.071224
# min       19.000000     19.000000
# 25%       96.000000     96.000000
# 50%      111.000000    111.000000
# 75%      128.000000    128.000000
# max      200.000000    200.000000

# %%
m = 0
M = 10
paso = 1
num_ratings_percentile = [(i, np.percentile(users_n_ratings['rating'], i)) for i in range(m, M + 1, paso)]

# Gráfica para comprobar qué porcentaje de libros tienen menos de 10k valoraciones
plt.plot([x[0] for x in num_ratings_percentile], [x[1] for x in num_ratings_percentile], 'bo-')
plt.axhline(y=20, color='r', linestyle='--')
plt.xticks(np.arange(m, M + 1, paso))
plt.xlabel('Percentil')
plt.ylabel('Número de valoraciones')
plt.title('Número de valoraciones en los percentiles inferiores')
plt.legend(['Número de valoraciones', 'Límite de 20 valoraciones'])
plt.show()

# %% [markdown]
# Como vemos, tanto por el resumen de los datos como por la gráfica, el dataset se compone de usuarios con más de 20 valoraciones de libros distintos (el mínimo es 19) y la gran mayoría (un 99%) ha reseñado 40 o más libros. Por tanto, a la hora de implementar el modelo recomendador, una de las entradas podría ser el perfil de usuario, construido en base a aquellos libros que ha valorado.
#
# Este dataset, además de ser robusto en cuanto a libros con un número significativo de valoraciones como habíamos comentado, también es relativamente fuerte si nos fijamos en la parte de usuario, ya que un mínimo de 20 libros valorados nos puede dar una idea lo suficientemente buena sobre sus preferencias como lector.

# %% [markdown]
# ### <a id="otros"></a> Otros datasets

# %% [markdown]
# El conglomerado de datasets también incluye otros como `book_tags.csv`, `tags.csv` o `to_read.csv`. Estos no nos interesarán, salvo quizá el último en combinación con `ratings.csv` (ayuda a comprender mejor el perfil de cada usuario, pues incluye una lista de libros que le interesaría leer en el futuro).
#
# No obstante, los datasets sobre *tags* pueden ofrecer ideas en cuanto a la extracción de información identificativa de los libros y su contenido, lo cual resulta similar a lo que se intentará realizar a partir de NLP con las sinopsis de los mismos.
